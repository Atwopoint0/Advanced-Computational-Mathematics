# %% [markdown]
# A form $(a, b, c)$ is ambiguous if it is equivalent to $(a, -b, c)$, i.e., the class has order $2$ or $1$. For a form to be reduced and ambiguous, its coefficients must satisfy one of three special conditions, $b = 0$, $b = a$ or $a = c$. There is a relationship between the reduced ambiguous forms and the factoriation of the discriminant $d$.
#
# *   Forms of type $(a, 0, c)$: These forms correspond directly to the ways that $-d/4$ can be written as a product of two coprime integers $a$ and $c$.
# *   Forms of type $(a, a, c)$ and $(a, b, a)$: These forms are related to factorisations of $-d$. The coefficients $a$ or $b$ appear as factors of $d$.
#
# Let $k$ be the number of distinct prime factors of the discriminant $d$. Then the number of reduced ambiguous forms is $2^{k-1}$.
#
# We wish to find a non-trivial factor of a given composite integer $N$ given the theory of binary quadratic forms. We take a discriminant $d = -kN$, with $k$ a small positive integer, and attempt to construct ambiguous forms of discriminant $d$. We repeatedly pick a form at random and raise it to a suitable power in the class group.
#
# To perform this method we require knowledge of the class number $h(d)$. Our existing method works by exhaustive search by enumerating all possible reduced forms for a given discriminant $d$ by iterating through all possible coefficients $a$ an $b$, of which there are proportionally $\sqrt{-d}$ of each, leading to a time complexity of $O(|d|)$. The magnitude of the discriminant $|d|$ is on the same order as the number we want to factor $N$, so the time complexity is $O(N)$. This is worse than trial division which is approximately $O(\sqrt{N})$.
#
# Instead we fix a positive integer $B$ and assume that $h(d)$ is a product of prime powers less than $B$. We choose a form of discriminant $d$ at random by choosing a small value of $a$, and then solving for $b$ and $c$ if possible. Then we successively raise it to each odd prime power less than $B$. We then repeatedly square (efficiently) this form in the hope of finding an ambiguous form that factors $N$. If this method repeatedly fails we might increase the value of $B$ or change the value of $k$.

# %%
import math

def reduce_form(a, b, c):
    '''
    Reduces a quadratic form (a,b,c) to its unique equivalent reduced form.
    '''
    while True:
        # Check if already reduced
        if -a < b <= a and a < c: break
        if 0 <= b <= a and a == c: break

        # Apply S transformation if a > c or a=c and b < 0
        if a > c or (a == c and b < 0):
            a, b, c = c, -b, a
            continue

        # Apply T^n or T^-n transformation to bring b into [-a, a]
        if b > a:
            n = (b + a) // (2 * a)
            b, c = b - 2*a*n, a*n*n - b*n + c
        elif b <= -a:
            n = (-b + a) // (2 * a)
            b, c = b + 2*a*n, a*n*n + b*n + c

    return (a, b, c)

def compose_forms(f1, f2, d):
    '''
    Computes the composition of two primitive forms with discriminant d.
    '''
    a1, b1, c1 = f1
    a2, b2, c2 = f2

    beta = (b1 + b2) // 2
    gamma = (b2 - b1) // 2

    # Use Extended Euclidean Algorithm to solve a1*x + beta*y = m
    m, x, _ = math.gcd(a1, beta), *extended_gcd(a1, beta)[1:]

    n = math.gcd(m, a2)

    # Solve the congruence (m/n)z = (gamma*x - c1*y) (mod a2/n)
    A = m // n
    B = gamma * x - c1 * _
    M = a2 // n
    z = (B * pow(A, -1, M)) % M

    a3 = (a1 * a2) // (n**2)
    b3 = b1 + (2 * a1 * z) // n
    c3 = (b3**2 - d) // (4 * a3)

    return reduce_form(a3, b3, c3)

def extended_gcd(a, b):
    if a == 0: return b, 0, 1
    g, y, x = extended_gcd(b % a, a)
    return g, x - (b // a) * y, y

# %%
def power(form, exp, d):
    '''
    Computes form^exp in the class group using exponentiation by squaring.
    '''
    # Determine the identity element
    if d % 4 == 0:
        identity = (1, 0, -d // 4)
    else:
        identity = (1, 1, (1 - d) // 4)

    result = identity
    base = form

    while exp > 0:
        if exp % 2 == 1:
            result = compose_forms(result, base, d)
        base = compose_forms(base, base, d)
        exp //= 2

    return result

def generate_primes(limit):
    '''
    Generate primes up to a limit using a sieve.
    '''
    primes = []
    is_prime = [True] * (limit + 1)
    is_prime[0] = is_prime[1] = False
    for p in range(2, limit + 1):
        if is_prime[p]:
            primes.append(p)
            for i in range(p * p, limit + 1, p):
                is_prime[i] = False
    return primes

def find_starting_form(d, N):
    '''
    Finds a suitable primitive form (a,b,c) for discriminant d.
    '''
    for a in generate_primes(100): # Try small prime 'a' values
        if N % a == 0: continue # 'a' should not be a factor of N

        # We need b^2 = d + 4ac, so b^2 = d (mod 4a)
        for b in range(1, 100):
            if (b*b - d) % (4*a) == 0:
                c = (b*b - d) // (4*a)
                # Ensure it's primitive
                if math.gcd(math.gcd(a,b),c) == 1:
                    return reduce_form(a, b, c)
    return None

def factor_with_forms(N, k, B):
    '''
    Attempts to factor N using the quadratic forms method with parameters k and B.
    '''
    d = -k * N
    if d % 4 not in (0, 1):
        # Invalid discriminant
        return None

    print(f"\n--- Factor N = {N} with k = {k}, B = {B}, d = {d} ---")

    # Find a starting form
    f_start = find_starting_form(d, N)
    if not f_start:
        print("  Could not find a suitable starting form.")
        return None
    print(f"Starting with form: f_start = {f_start}")

    # Raise to the power of all odd prime powers < B
    primes = generate_primes(B)
    E = 1
    for p in primes:
        if p == 2: continue
        p_power = p
        while p_power <= B / p:
            p_power *= p
        E *= p_power

    f_E = power(f_start, E, d)
    print(f"After raising to prime powers < {B}, form is: f_E = {f_E}")

    # Repeatedly square to find an ambiguous form
    g = f_E
    for i in range(1, 100): # Limit squaring to prevent infinite loops
        g = compose_forms(g, g, d)
        # Check for ambiguity
        a, b, c = g
        if b == 0 or b == a or a == c:
            # Ambiguous form found

            # Find factor using GCD
            factor = math.gcd(N, a)
            if 1 < factor < N:
                print(f"\nFound non-trivial factor: {factor}")
                return factor
            else:
                # Ambiguous form gave trivial factor
                pass

    print("Failed to find a factor after extensive squaring.")
    return None

numbers_to_factor = [12597203, 33377419, 49047121]
B_LIMIT = 50
K_LIMIT = 200

for N in numbers_to_factor:
    print(f"=" * 30)
    print(f"Processing N = {N}")
    print(f"=" * 30)
    found_factor = False
    for k_val in range(1, K_LIMIT + 1):
        factor = factor_with_forms(N, k_val, B_LIMIT)
        if factor:
            print(f"Factorisation of {N} is {factor} * {N // factor}\n")
            found_factor = True
            break
    if not found_factor:
        print(f"\nNo factor found for N={N} with k up to {K_LIMIT}.\n")
# Out:
# ==============================
# Processing N = 12597203
# ==============================
#
# --- Factor N = 12597203 with k = 1, B = 50, d = -12597203 ---
# Starting with form: f_start = (3, 1, 1049767)
# After raising to prime powers < 50, form is: f_E = (699, 349, 4549)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 12597203 with k = 4, B = 50, d = -50388812 ---
# Starting with form: f_start = (3, 2, 4199068)
# After raising to prime powers < 50, form is: f_E = (2796, -2098, 4899)
#
# Found non-trivial factor: 2153
# Factorisation of 12597203 is 2153 * 5851
#
# ==============================
# Processing N = 33377419
# ==============================
#
# --- Factor N = 33377419 with k = 1, B = 50, d = -33377419 ---
# Starting with form: f_start = (5, 1, 1668871)
# After raising to prime powers < 50, form is: f_E = (325, 9, 25675)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 4, B = 50, d = -133509676 ---
# Starting with form: f_start = (5, 2, 6675484)
# After raising to prime powers < 50, form is: f_E = (1300, -1282, 25991)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 5, B = 50, d = -166887095 ---
# Starting with form: f_start = (2, 1, 20860887)
# After raising to prime powers < 50, form is: f_E = (7302, 6811, 7302)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 8, B = 50, d = -267019352 ---
# Starting with form: f_start = (2, 0, 33377419)
# After raising to prime powers < 50, form is: f_E = (2, 0, 33377419)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 9, B = 50, d = -300396771 ---
# Starting with form: f_start = (5, 3, 15019839)
# After raising to prime powers < 50, form is: f_E = (2925, 1977, 26009)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 12, B = 50, d = -400529028 ---
# Starting with form: f_start = (2, 2, 50066129)
# After raising to prime powers < 50, form is: f_E = (2, 2, 50066129)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 13, B = 50, d = -433906447 ---
# Starting with form: f_start = (2, 1, 54238306)
# After raising to prime powers < 50, form is: f_E = (5302, -3335, 20984)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 16, B = 50, d = -534038704 ---
# Starting with form: f_start = (5, 4, 26701936)
# After raising to prime powers < 50, form is: f_E = (5200, 2636, 26009)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 17, B = 50, d = -567416123 ---
# Starting with form: f_start = (3, 1, 47284677)
# After raising to prime powers < 50, form is: f_E = (12393, 10421, 13637)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 20, B = 50, d = -667548380 ---
# Starting with form: f_start = (3, 2, 55629032)
# After raising to prime powers < 50, form is: f_E = (4283, 0, 38965)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 21, B = 50, d = -700925799 ---
# Starting with form: f_start = (2, 1, 87615725)
# After raising to prime powers < 50, form is: f_E = (12849, 12849, 16850)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 24, B = 50, d = -801058056 ---
# Starting with form: f_start = (2, 0, 100132257)
# After raising to prime powers < 50, form is: f_E = (2, 0, 100132257)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 25, B = 50, d = -834435475 ---
# Starting with form: f_start = (7, 1, 29801267)
# After raising to prime powers < 50, form is: f_E = (6497, 655, 32125)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 28, B = 50, d = -934567732 ---
# Starting with form: f_start = (2, 2, 116820967)
# After raising to prime powers < 50, form is: f_E = (2, 2, 116820967)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 29, B = 50, d = -967945151 ---
# Starting with form: f_start = (2, 1, 120993144)
# After raising to prime powers < 50, form is: f_E = (2156, -633, 112285)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 32, B = 50, d = -1068077408 ---
# Starting with form: f_start = (3, 2, 89006451)
# After raising to prime powers < 50, form is: f_E = (15048, 12400, 20299)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 33, B = 50, d = -1101454827 ---
# Starting with form: f_start = (3, 3, 91787903)
# After raising to prime powers < 50, form is: f_E = (3, 3, 91787903)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 36, B = 50, d = -1201587084 ---
# Starting with form: f_start = (5, 4, 60079355)
# After raising to prime powers < 50, form is: f_E = (11700, -3954, 26009)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 37, B = 50, d = -1234964503 ---
# Starting with form: f_start = (2, 1, 154370563)
# After raising to prime powers < 50, form is: f_E = (14129, 767, 21862)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 40, B = 50, d = -1335096760 ---
# Starting with form: f_start = (2, 0, 166887095)
# After raising to prime powers < 50, form is: f_E = (2, 0, 166887095)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 41, B = 50, d = -1368474179 ---
# Starting with form: f_start = (3, 1, 114039515)
# After raising to prime powers < 50, form is: f_E = (4353, 4339, 79675)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 44, B = 50, d = -1468606436 ---
# Starting with form: f_start = (2, 2, 183575805)
# After raising to prime powers < 50, form is: f_E = (2, 2, 183575805)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 45, B = 50, d = -1501983855 ---
# Starting with form: f_start = (2, 1, 187747982)
# After raising to prime powers < 50, form is: f_E = (7793, 7793, 50132)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 48, B = 50, d = -1602116112 ---
# Starting with form: f_start = (3, 0, 133509676)
# After raising to prime powers < 50, form is: f_E = (3, 0, 133509676)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 49, B = 50, d = -1635493531 ---
# Starting with form: f_start = (5, 3, 81774677)
# After raising to prime powers < 50, form is: f_E = (15925, 13587, 28573)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 52, B = 50, d = -1735625788 ---
# Starting with form: f_start = (11, 4, 39446041)
# After raising to prime powers < 50, form is: f_E = (18973, -1272, 22891)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 53, B = 50, d = -1769003207 ---
# Starting with form: f_start = (2, 1, 221125401)
# After raising to prime powers < 50, form is: f_E = (13704, 6923, 33146)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 56, B = 50, d = -1869135464 ---
# Starting with form: f_start = (2, 0, 233641933)
# After raising to prime powers < 50, form is: f_E = (2, 0, 233641933)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 57, B = 50, d = -1902512883 ---
# Starting with form: f_start = (3, 3, 158542741)
# After raising to prime powers < 50, form is: f_E = (3, 3, 158542741)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 60, B = 50, d = -2002645140 ---
# Starting with form: f_start = (2, 2, 250330643)
# After raising to prime powers < 50, form is: f_E = (2, 2, 250330643)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 61, B = 50, d = -2036022559 ---
# Starting with form: f_start = (2, 1, 254502820)
# After raising to prime powers < 50, form is: f_E = (21830, -9261, 24299)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 64, B = 50, d = -2136154816 ---
# Starting with form: f_start = (5, 2, 106807741)
# After raising to prime powers < 50, form is: f_E = (20800, 15528, 28573)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 65, B = 50, d = -2169532235 ---
# Starting with form: f_start = (3, 1, 180794353)
# After raising to prime powers < 50, form is: f_E = (20693, -17219, 29793)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 68, B = 50, d = -2269664492 ---
# Starting with form: f_start = (3, 2, 189138708)
# After raising to prime powers < 50, form is: f_E = (12393, -3944, 46099)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 69, B = 50, d = -2303041911 ---
# Starting with form: f_start = (2, 1, 287880239)
# After raising to prime powers < 50, form is: f_E = (23330, 16337, 27539)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 72, B = 50, d = -2403174168 ---
# Starting with form: f_start = (2, 0, 300396771)
# After raising to prime powers < 50, form is: f_E = (2, 0, 300396771)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 73, B = 50, d = -2436551587 ---
# Starting with form: f_start = (11, 5, 55376173)
# After raising to prime powers < 50, form is: f_E = (7393, 1999, 82529)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 76, B = 50, d = -2536683844 ---
# Starting with form: f_start = (2, 2, 317085481)
# After raising to prime powers < 50, form is: f_E = (2, 2, 317085481)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 77, B = 50, d = -2570061263 ---
# Starting with form: f_start = (2, 1, 321257658)
# After raising to prime powers < 50, form is: f_E = (13899, -503, 46232)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 80, B = 50, d = -2670193520 ---
# Starting with form: f_start = (3, 2, 222516127)
# After raising to prime powers < 50, form is: f_E = (4283, 0, 155860)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 81, B = 50, d = -2703570939 ---
# Starting with form: f_start = (5, 1, 135178547)
# After raising to prime powers < 50, form is: f_E = (26009, 5931, 26325)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 84, B = 50, d = -2803703196 ---
# Starting with form: f_start = (3, 0, 233641933)
# After raising to prime powers < 50, form is: f_E = (3, 0, 233641933)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 85, B = 50, d = -2837080615 ---
# Starting with form: f_start = (2, 1, 354635077)
# After raising to prime powers < 50, form is: f_E = (19712, 11931, 37787)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 88, B = 50, d = -2937212872 ---
# Starting with form: f_start = (2, 0, 367151609)
# After raising to prime powers < 50, form is: f_E = (2, 0, 367151609)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 89, B = 50, d = -2970590291 ---
# Starting with form: f_start = (3, 1, 247549191)
# After raising to prime powers < 50, form is: f_E = (18091, -8809, 42123)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 92, B = 50, d = -3070722548 ---
# Starting with form: f_start = (2, 2, 383840319)
# After raising to prime powers < 50, form is: f_E = (2, 2, 383840319)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 93, B = 50, d = -3104099967 ---
# Starting with form: f_start = (2, 1, 388012496)
# After raising to prime powers < 50, form is: f_E = (15144, 2751, 51368)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 96, B = 50, d = -3204232224 ---
# Starting with form: f_start = (3, 0, 267019352)
# After raising to prime powers < 50, form is: f_E = (3, 0, 267019352)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 97, B = 50, d = -3237609643 ---
# Starting with form: f_start = (17, 13, 47611909)
# After raising to prime powers < 50, form is: f_E = (4283, 4283, 190051)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 100, B = 50, d = -3337741900 ---
# Starting with form: f_start = (7, 2, 119205068)
# After raising to prime powers < 50, form is: f_E = (25988, -24678, 37967)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 101, B = 50, d = -3371119319 ---
# Starting with form: f_start = (2, 1, 421389915)
# After raising to prime powers < 50, form is: f_E = (11745, 9779, 73792)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 104, B = 50, d = -3471251576 ---
# Starting with form: f_start = (2, 0, 433906447)
# After raising to prime powers < 50, form is: f_E = (2, 0, 433906447)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 105, B = 50, d = -3504628995 ---
# Starting with form: f_start = (3, 3, 292052417)
# After raising to prime powers < 50, form is: f_E = (3, 3, 292052417)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 108, B = 50, d = -3604761252 ---
# Starting with form: f_start = (2, 2, 450595157)
# After raising to prime powers < 50, form is: f_E = (2, 2, 450595157)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 109, B = 50, d = -3638138671 ---
# Starting with form: f_start = (2, 1, 454767334)
# After raising to prime powers < 50, form is: f_E = (7793, 7793, 118660)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 112, B = 50, d = -3738270928 ---
# Starting with form: f_start = (7, 0, 133509676)
# After raising to prime powers < 50, form is: f_E = (7, 0, 133509676)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 113, B = 50, d = -3771648347 ---
# Starting with form: f_start = (3, 1, 314304029)
# After raising to prime powers < 50, form is: f_E = (24579, -13741, 40283)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 116, B = 50, d = -3871780604 ---
# Starting with form: f_start = (3, 2, 322648384)
# After raising to prime powers < 50, form is: f_E = (19767, 14840, 51753)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 117, B = 50, d = -3905158023 ---
# Starting with form: f_start = (2, 1, 488144753)
# After raising to prime powers < 50, form is: f_E = (29621, 17425, 35522)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 120, B = 50, d = -4005290280 ---
# Starting with form: f_start = (2, 0, 500661285)
# After raising to prime powers < 50, form is: f_E = (2, 0, 500661285)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 121, B = 50, d = -4038667699 ---
# Starting with form: f_start = (5, 1, 201933385)
# After raising to prime powers < 50, form is: f_E = (33845, 31841, 37321)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 124, B = 50, d = -4138799956 ---
# Starting with form: f_start = (2, 2, 517349995)
# After raising to prime powers < 50, form is: f_E = (2, 2, 517349995)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 125, B = 50, d = -4172177375 ---
# Starting with form: f_start = (2, 1, 521522172)
# After raising to prime powers < 50, form is: f_E = (7793, 7793, 135792)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 128, B = 50, d = -4272309632 ---
# Starting with form: f_start = (3, 2, 356025803)
# After raising to prime powers < 50, form is: f_E = (22947, 10502, 47747)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 129, B = 50, d = -4305687051 ---
# Starting with form: f_start = (3, 3, 358807255)
# After raising to prime powers < 50, form is: f_E = (3, 3, 358807255)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 132, B = 50, d = -4405819308 ---
# Starting with form: f_start = (3, 0, 367151609)
# After raising to prime powers < 50, form is: f_E = (3, 0, 367151609)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 133, B = 50, d = -4439196727 ---
# Starting with form: f_start = (2, 1, 554899591)
# After raising to prime powers < 50, form is: f_E = (32327, 30115, 41344)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 136, B = 50, d = -4539328984 ---
# Starting with form: f_start = (2, 0, 567416123)
# After raising to prime powers < 50, form is: f_E = (2, 0, 567416123)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 137, B = 50, d = -4572706403 ---
# Starting with form: f_start = (3, 1, 381058867)
# After raising to prime powers < 50, form is: f_E = (11049, 10145, 105793)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 140, B = 50, d = -4672838660 ---
# Starting with form: f_start = (2, 2, 584104833)
# After raising to prime powers < 50, form is: f_E = (2, 2, 584104833)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 141, B = 50, d = -4706216079 ---
# Starting with form: f_start = (2, 1, 588277010)
# After raising to prime powers < 50, form is: f_E = (15491, -10623, 77772)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 144, B = 50, d = -4806348336 ---
# Starting with form: f_start = (5, 2, 240317417)
# After raising to prime powers < 50, form is: f_E = (26009, -7908, 46800)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 145, B = 50, d = -4839725755 ---
# Starting with form: f_start = (5, 5, 241986289)
# After raising to prime powers < 50, form is: f_E = (5, 5, 241986289)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 148, B = 50, d = -4939858012 ---
# Starting with form: f_start = (7, 4, 176423501)
# After raising to prime powers < 50, form is: f_E = (2488, -2046, 496789)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 149, B = 50, d = -4973235431 ---
# Starting with form: f_start = (2, 1, 621654429)
# After raising to prime powers < 50, form is: f_E = (17294, 6249, 72457)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 152, B = 50, d = -5073367688 ---
# Starting with form: f_start = (2, 0, 634170961)
# After raising to prime powers < 50, form is: f_E = (2, 0, 634170961)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 153, B = 50, d = -5106745107 ---
# Starting with form: f_start = (11, 3, 116062389)
# After raising to prime powers < 50, form is: f_E = (21447, 10161, 60731)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 156, B = 50, d = -5206877364 ---
# Starting with form: f_start = (2, 2, 650859671)
# After raising to prime powers < 50, form is: f_E = (2, 2, 650859671)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 157, B = 50, d = -5240254783 ---
# Starting with form: f_start = (2, 1, 655031848)
# After raising to prime powers < 50, form is: f_E = (11213, -11081, 119572)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 160, B = 50, d = -5340387040 ---
# Starting with form: f_start = (5, 0, 267019352)
# After raising to prime powers < 50, form is: f_E = (5, 0, 267019352)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 161, B = 50, d = -5373764459 ---
# Starting with form: f_start = (3, 1, 447813705)
# After raising to prime powers < 50, form is: f_E = (27935, -13941, 49831)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 164, B = 50, d = -5473896716 ---
# Starting with form: f_start = (3, 2, 456158060)
# After raising to prime powers < 50, form is: f_E = (17412, -8734, 79689)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 33377419 with k = 165, B = 50, d = -5507274135 ---
# Starting with form: f_start = (2, 1, 688409267)
# After raising to prime powers < 50, form is: f_E = (15542, 9721, 90107)
#
# Found non-trivial factor: 4283
# Factorisation of 33377419 is 4283 * 7793
#
# ==============================
# Processing N = 49047121
# ==============================
#
# --- Factor N = 49047121 with k = 3, B = 50, d = -147141363 ---
# Starting with form: f_start = (3, 3, 12261781)
# After raising to prime powers < 50, form is: f_E = (3, 3, 12261781)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 4, B = 50, d = -196188484 ---
# Starting with form: f_start = (2, 2, 24523561)
# After raising to prime powers < 50, form is: f_E = (2, 2, 24523561)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 7, B = 50, d = -343329847 ---
# Starting with form: f_start = (2, 1, 42916231)
# After raising to prime powers < 50, form is: f_E = (3994, -531, 21508)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 8, B = 50, d = -392376968 ---
# Starting with form: f_start = (2, 0, 49047121)
# After raising to prime powers < 50, form is: f_E = (2, 0, 49047121)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 11, B = 50, d = -539518331 ---
# Starting with form: f_start = (3, 1, 44959861)
# After raising to prime powers < 50, form is: f_E = (2643, -1891, 51371)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 12, B = 50, d = -588565452 ---
# Starting with form: f_start = (3, 0, 49047121)
# After raising to prime powers < 50, form is: f_E = (3, 0, 49047121)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 15, B = 50, d = -735706815 ---
# Starting with form: f_start = (2, 1, 91963352)
# After raising to prime powers < 50, form is: f_E = (7388, 2089, 25043)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 16, B = 50, d = -784753936 ---
# Starting with form: f_start = (5, 2, 39237697)
# After raising to prime powers < 50, form is: f_E = (10645, 9842, 20705)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 19, B = 50, d = -931895299 ---
# Starting with form: f_start = (5, 1, 46594765)
# After raising to prime powers < 50, form is: f_E = (5545, -4051, 42755)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 20, B = 50, d = -980942420 ---
# Starting with form: f_start = (2, 2, 122617803)
# After raising to prime powers < 50, form is: f_E = (2, 2, 122617803)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 23, B = 50, d = -1128083783 ---
# Starting with form: f_start = (2, 1, 141010473)
# After raising to prime powers < 50, form is: f_E = (8217, -3121, 34618)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 24, B = 50, d = -1177130904 ---
# Starting with form: f_start = (2, 0, 147141363)
# After raising to prime powers < 50, form is: f_E = (2, 0, 147141363)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 27, B = 50, d = -1324272267 ---
# Starting with form: f_start = (7, 5, 47295439)
# After raising to prime powers < 50, form is: f_E = (18823, -10173, 18963)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 28, B = 50, d = -1373319388 ---
# Starting with form: f_start = (7, 0, 49047121)
# After raising to prime powers < 50, form is: f_E = (7, 0, 49047121)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 31, B = 50, d = -1520460751 ---
# Starting with form: f_start = (2, 1, 190057594)
# After raising to prime powers < 50, form is: f_E = (7907, 7907, 50050)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 32, B = 50, d = -1569507872 ---
# Starting with form: f_start = (3, 2, 130792323)
# After raising to prime powers < 50, form is: f_E = (18547, -116, 21156)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 35, B = 50, d = -1716649235 ---
# Starting with form: f_start = (3, 1, 143054103)
# After raising to prime powers < 50, form is: f_E = (3183, 2333, 135257)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 36, B = 50, d = -1765696356 ---
# Starting with form: f_start = (2, 2, 220712045)
# After raising to prime powers < 50, form is: f_E = (2, 2, 220712045)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 39, B = 50, d = -1912837719 ---
# Starting with form: f_start = (2, 1, 239104715)
# After raising to prime powers < 50, form is: f_E = (12170, 7149, 40344)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 40, B = 50, d = -1961884840 ---
# Starting with form: f_start = (2, 0, 245235605)
# After raising to prime powers < 50, form is: f_E = (2, 0, 245235605)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 43, B = 50, d = -2109026203 ---
# Starting with form: f_start = (17, 11, 31015093)
# After raising to prime powers < 50, form is: f_E = (4223, 1283, 124951)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 44, B = 50, d = -2158073324 ---
# Starting with form: f_start = (3, 2, 179839444)
# After raising to prime powers < 50, form is: f_E = (2643, 1504, 204345)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 47, B = 50, d = -2305214687 ---
# Starting with form: f_start = (2, 1, 288151836)
# After raising to prime powers < 50, form is: f_E = (13808, -10255, 43641)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 48, B = 50, d = -2354261808 ---
# Starting with form: f_start = (3, 0, 196188484)
# After raising to prime powers < 50, form is: f_E = (3, 0, 196188484)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 51, B = 50, d = -2501403171 ---
# Starting with form: f_start = (3, 3, 208450265)
# After raising to prime powers < 50, form is: f_E = (3, 3, 208450265)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 52, B = 50, d = -2550450292 ---
# Starting with form: f_start = (2, 2, 318806287)
# After raising to prime powers < 50, form is: f_E = (2, 2, 318806287)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 55, B = 50, d = -2697591655 ---
# Starting with form: f_start = (2, 1, 337198957)
# After raising to prime powers < 50, form is: f_E = (25352, 1259, 26617)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 56, B = 50, d = -2746638776 ---
# Starting with form: f_start = (2, 0, 343329847)
# After raising to prime powers < 50, form is: f_E = (2, 0, 343329847)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 59, B = 50, d = -2893780139 ---
# Starting with form: f_start = (3, 1, 241148345)
# After raising to prime powers < 50, form is: f_E = (18225, 7081, 40383)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 60, B = 50, d = -2942827260 ---
# Starting with form: f_start = (3, 0, 245235605)
# After raising to prime powers < 50, form is: f_E = (3, 0, 245235605)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 63, B = 50, d = -3089968623 ---
# Starting with form: f_start = (2, 1, 386246078)
# After raising to prime powers < 50, form is: f_E = (26033, -25557, 35946)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 64, B = 50, d = -3139015744 ---
# Starting with form: f_start = (5, 4, 156950788)
# After raising to prime powers < 50, form is: f_E = (10645, -1606, 73781)
# Failed to find a factor after extensive squaring.
#
# --- Factor N = 49047121 with k = 67, B = 50, d = -3286157107 ---
# Starting with form: f_start = (11, 3, 74685389)
# After raising to prime powers < 50, form is: f_E = (8851, 4493, 93389)
#
# Found non-trivial factor: 6203
# Factorisation of 49047121 is 6203 * 7907

# %% [markdown]
# The fundamental operations of the entire process is the composition of two forms followed by a reduction. The inputs to this operation are the coefficients $(a, b, c)$ of reduced forms whose sizes are bounded by the discriminant $d = -kN$. Specifically, $a$ can be as large as $O(\sqrt{|d|}) = O(\sqrt{N})$.
#
# The composition operation relies on the extended Euclidean algorithm. The complexity on numbers of size $X$ is polynomial in the number of bits, roughly $O(\log^2 X)$. Since our coefficients are up to $O(\sqrt{N})$, this is $O(\log N)$. Therefore, the time complexity of a single composition followed by a reduction is $O(\log^2 N)$.
#
# The most computationally expensive part of the algorithm is raising the initial form $f$ to the large exponent $E$. The number of compositions it must perform is proportional to the number of bits in the exponent $O(\log E)$. The exponent $E$ is the product of all odd prime powers less than $B$, so $\log E$ is the sum of the logarithms of these prime powers. The prime number theorem shows that $O(\log E) = O(B)$.
#
# Combining these, the total time for this main step is $O(B \log^2 N)$.
#
# *   If we choose a small $B$, the exponentiation step is fast. However, the chance that the class number $h(d)$ is $B$-smooth is low. This means we might have to try many values of $k$ or perform many squarings, making the algorithm run for a long time.
# *   If we choose a large $B$, the chance of $h(d)$ being B-smooth is much higher, making the algorithm more likely to succeed quickly. However, the exponentiation step now becomes very slow.
#
# The optimal strategy is to choose a value for $B$ that balances these two competing factors. When this optimisation is done, the resulting complexity is sub-exponential. It is expressed using $L$-notation as
# \begin{equation}
#     L_N[1/2, c] = \exp(c \sqrt{\log N \cdot \log\log N})
# \end{equation}
# where $c$ is a small constant.
#
# *   Trial division has a complexity of $O(\sqrt{N})$ which in L-notation is $L_N[1, 1/2]$, hence is exponential.
# *   General number field sieve is the fastest known classical factoring algorithm with complexity is $L_N[1/3, c]$. It is asymptotically faster than the class group method because the term in the exponent is $(\log N)^{1/3}$ instead of $(\log N)^{1/2}$.
# *   Shor's algorithm in quantum computing has a complexity of $O(\log^3 N)$ which is of polynomial time and is therefore theoretically much faster than any of the classical algorithms.
